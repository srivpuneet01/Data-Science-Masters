# %%
from bs4 import BeautifulSoup
from collections import Counter
from string import punctuation
import urllib.request
import nltk

# %%
response = urllib.request.urlopen('https://en.wikipedia.org/wiki/Twenty_One_Pilots')
html = response.read()
soup = BeautifulSoup(html,"html5lib")

# %%
text = (''.join(s.findAll(text=True))for s in soup.findAll('a'))

c = Counter((x.rstrip(punctuation).lower() for y in text for x in y.split()))
# Print most common words
print (c.most_common())
# Out:
# [('', 211), ('one', 175), ('pilots', 172), ('"twenty', 92), ('twenty', 79), ('the', 71), ('a', 47), ('and', 37), ('in', 34), ('tour', 33), ('b', 32), ('to', 29), ('of', 29), ('on', 28), ('with', 27), ('at', 25), ('rock', 23), ('new', 23), ('music', 23), ('for', 20), ('album', 19), ('out', 17), ('wikipedia', 15), ('best', 14), ('awards', 14), ('billboard', 14), ('video', 14), ('by', 13), ('from', 13), ('joseph', 12), ('blurryface', 12), ('songs', 12), ('original', 12), ('ohio', 11), ('tyler', 11), ('band', 11), ('my', 11), ('live', 11), ('articles', 11), ('alternative', 9), ('pop', 9), ('vessel', 9), ('1', 9), ('c', 9), ('columbus', 8), ('josh', 8), ('dun', 8), ('trench', 8), ('"the', 8), ('announce', 8), ('squad', 7), ('regional', 7), ('gold', 7), ('hot', 7), ('emotional', 7), ('roadshow', 7), ('world', 7), ('american', 7), ('arena', 7), ('niners', 7), ('blood', 7), ('chris', 7), ('about', 7), ('their', 7), ('identifiers', 7), ('fueled', 6), ('ramen', 6), ('grammy', 6), ('radio', 6), ('you', 6), ('sleep', 6), ('list', 6), ('"hear', 6), ('release', 6), ('show', 6), ('fans', 6), ('perform', 6), ('dates', 6), ('groups', 6), ('indie', 5), ('stressed', 5), ('suicide', 5), ('award', 5), ('[6', 5), ('come', 5), ('hands', 5), ('holding', 5), ('night', 5), ('london', 5), ('bandito', 5), ('"interview', 5), ('part', 5), ('salih', 5), ('up', 5), ('that', 5), ('single', 5), ('"watch', 5), ('watch', 5), ("'blurryface", 5), ('talk', 5), ('are', 5), ('hip', 4), ('hop', 4), ('heathens', 4), ('performance', 4), ('history', 4), ('discography', 4), ('links', 4), ('house', 4), ('youtube', 4), ('car', 4), ('guns', 4), ('200', 4), ('100', 4), ('fall', 4), ('boy', 4), ('mtv', 4), ('local', 4), ('tear', 4), ('heart', 4), ('mutemath', 4), ('2016', 4), ('theatre', 4), ('nico', 4), ('2018', 4), ('[174', 4), ('chart', 4), ('store', 4), ('interview', 4), ('"vessel', 4), ('off', 4), ('"tyler', 4), ('we', 4), ('twitter', 4), ('this', 4), ('first', 4), ('complete', 4), ('reddit', 4), ('song', 4), ('sound', 4), ('just', 4), ('lounge', 4), ('review', 4), ('biggest', 4), ('pages', 4), ('page', 4), ('(album', 3), ('electropop', 3), ('rap', 3), ('ride', 3), ('duo/group', 3), ('changes', 3), ('label', 3), ('nominations', 3), ('see', 3), ('10', 3), ('[4', 3), ('no', 3), ('o', 3), ('albany', 3), ('panic', 3), ('disco', 3), ('paramore', 3), ('neon', 3), ('ode', 3), ('lovely', 3), ('save', 3), ('roll', 3), ('2014', 3), ('chemical', 3), ('nationwide', 3), ('riaa', 3), ('jumpsuit', 3), ('chlorine', 3), ('media', 3), ('help', 3), ('[150', 3), ('[156', 3), ('[159', 3), ('[164', 3), ('[165', 3), ('[177', 3), ("'nico", 3), ('"episode', 3), ('biography', 3), ('duo', 3), ('"founding', 3), ('member', 3), ('opens', 3), ('(moderately', 3), ('inspiring', 3), ('tale', 3), ('longboard', 3), ('rodeo', 3), ('tango', 3), ('episode', 3), ('source', 3), ('july', 3), ('version', 3), ("'ode", 3), ('more', 3), ('[official', 3), ("'stressed", 3), ('winners', 3), ('announces', 3), ('here', 3), ('cover', 3), ('2017', 3), ("'trench", 3), ('news', 3), ("'my", 3), ('top', 3), ('–', 3), ('art', 3), ('musical', 3), ('view', 3), ('jump', 2), ('atlantic', 2), ('[3', 2), ('major', 2), ('2', 2), ('3', 2), ('fandom', 2), ('concert', 2), ('act', 2), ('9', 2), ('[5', 2), ('[9', 2), ('state', 2), ('university', 2), ('[10', 2), ('[15', 2), ('emmanuel', 2), ('[29', 2), ('newport', 2), ('hall', 2), ('[35', 2), ('[37', 2), ('[41', 2), ('[42', 2), ('channel', 2), ('[43', 2), ('[44', 2), ('records', 2), ('trees', 2), ('walk', 2), ('moon', 2), ('post', 2), ('[56', 2), ('[57', 2), ('[61', 2), ('mtvu', 2), ('movie', 2), ('late', 2), ('seth', 2), ('meyers', 2), ('[71', 2), ('[74', 2), ('fairly', 2), ('beatles', 2), ('elvis', 2), ('macklemore', 2), ('fox', 2), ('press', 2), ('hometown', 2), ('zane', 2), ('lowe', 2), ('beats', 2), ('levitate', 2), ('[157', 2), ('[160', 2), ('[169', 2), ('[173', 2), ('[176', 2), ('[183', 2), ('all', 2), ('tube', 2), ('station', 2), ('singles', 2), ('artists', 2), ('itunes', 2), ("'jump ...
